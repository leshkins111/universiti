# %% [markdown]
# <a href="https://colab.research.google.com/github/leshkins111/universiti/blob/main/tasks/first_program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hi world')
# Out:
#   File "/tmp/ipykernel_884/1778610104.py", line 1
#     print(hi world)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
